# %%
from IPython.display import Image
from PIL import Image 

moustique = Image.open("moustique.jpg") 

format=moustique.format
print(format)

mode=moustique.mode
print(mode)

taille=moustique.size
print(taille)

r,v,b=moustique.getpixel((100,100))
print(" rouge_p1:",r," vert_p1:",v," bleu_p1:",b)

r,v,b=moustique.getpixel((150,150))
print(" rouge_p2:",r," vert_p2:",v," bleu_p2:",b)

r,v,b=moustique.getpixel((200,200))
print(" rouge_p3:",r," vert_p3:",v," bleu_p3:",b)

display(moustique)
# Out:
# JPEG
# RGB
# (1256, 708)
#  rouge_p1: 120  vert_p1: 145  bleu_p1: 54
#  rouge_p2: 79  vert_p2: 106  bleu_p2: 27
#  rouge_p3: 60  vert_p3: 89  bleu_p3: 22
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1256x708 at 0x6158088>
